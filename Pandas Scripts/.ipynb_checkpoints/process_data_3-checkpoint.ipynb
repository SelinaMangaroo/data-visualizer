# %%
import pandas as pd

df = pd.read_csv('/Users/selinamangaroo/Desktop/Pandas Scripts/data_processing/processed_1.csv', index_col=0)

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3395 entries, 1 to 3395
# Columns: 108 entries, accessno to ppid
# dtypes: bool(1), float64(38), int64(7), object(62)
# memory usage: 2.8+ MB
# None

# %%
df.head(10)
# Out:
#       accessno  acqvalue caption catby     catdate  cattype  circum  circumft  \
# 1       85-3-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 2       85-4-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 3       85-5-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 4   85-6-1 a&b       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 5       85-8-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 6       85-9-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 7      85-10-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 8      85-11-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 9      85-12-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
# 10     85-14-1       0.0     NaN   NaN  2010-06-11  History     0.0       0.0
#
#     circumin collection  ... weight weightin weightlb width widthft  widthin  \
# 1        0.0        NaN  ...    0.0      0.0      0.0  10.0     0.0      0.0
# 2        0.0        NaN  ...    0.0      0.0      0.0   6.0     0.0      0.0
# 3        0.0        NaN  ...    0.0      0.0      0.0  13.0     0.0      0.0
# 4        0.0        NaN  ...    0.0      0.0      0.0   5.0     0.0      0.0
# 5        0.0        NaN  ...    0.0      0.0      0.0   1.3     0.0      0.0
# 6        0.0        NaN  ...    0.0      0.0      0.0   1.7     0.0      0.0
# 7        0.0        NaN  ...    0.0      0.0      0.0   1.6     0.0      0.0
# 8        0.0        NaN  ...    0.0      0.0      0.0   6.0     0.0      0.0
# 9        0.0        NaN  ...    0.0      0.0      0.0   8.4     0.0      0.0
# 10       0.0        NaN  ...    0.0      0.0      0.0   2.4     0.0      0.0
#
#    xcord ycord  zcord                                  ppid
# 1    0.0   0.0    0.0  3C03818F-EA5B-40ED-8A51-511637772340
# 2    0.0   0.0    0.0  ADBDA490-9B39-4DE3-8FEF-223409360298
# 3    0.0   0.0    0.0  DC72DA26-4A4A-47EB-BEB8-379723716458
# 4    0.0   0.0    0.0  4D42FA5D-1D04-48CD-A0B5-032117625885
# 5    0.0   0.0    0.0  D9DBEFC1-569E-469D-917C-838844896574
# 6    0.0   0.0    0.0  B3039ED6-C319-40E4-9055-273701418584
# 7    0.0   0.0    0.0  33A4D8A6-9C4D-486C-91CF-137343693354
# 8    0.0   0.0    0.0  AE1778F5-2754-41DE-9270-450768636770
# 9    0.0   0.0    0.0  EDCA645C-5224-47BC-915F-349570603326
# 10   0.0   0.0    0.0  BD0EB99F-3ADC-4D29-9A9F-460830437190
#
# [10 rows x 108 columns]

# %%
df.loc[(df.type == 'physical_object'),'type'] = 'artifact'

# %%
new_df = df[["objectid", "objname", "type", "descrip", "date", "notes", "invnby", "invndate", "material"]]
new_df = new_df.head(10)
new_df
# Out:
#           objectid            objname      type  \
# 1     1937.095.003             Bodice  artifact
# 2     1937.095.001              Skirt  artifact
# 3     1937.095.009              Skirt  artifact
# 4     1937.095.002  Uniform, Military  artifact
# 5     1941.235.001      Gown, Wedding  artifact
# 6     1944.425.001      Gown, Wedding  artifact
# 7     1948.635.039      Gown, Wedding  artifact
# 8   1948.635.039 b      Gown, Wedding  artifact
# 9   1948.635.039 c              Scrap  artifact
# 10    2006.236.001               Suit  artifact
#
#                                               descrip  date  \
# 1   Bodice; velvet fabric; royal blue; lined with ...  1857
# 2   (b) Skirt; Sides and front are patterned silk ...  1857
# 3   Velvet; royal blue; three panels; 42-1/2"L; 7"...  1857
# 4   Uniform Coat: Civil War: Uniform fitted frock ...   NaN
# 5   Gown, Wedding; Two-piece wedding gown; faille ...  1886
# 6   Gown, wedding; satin fabric; deep ivory; one-p...  1880
# 7   Gown, Wedding;  bodice, white wool challis fab...  1873
# 8   Gown; Wedding gown skirt, white challis wool; ...  1873
# 9   Two cut and sewn pieces, with stitches undone....  1873
# 10  Linen fabric; navy color; 39"L shoulder to hem...  1912
#
#                                                 notes            invnby  \
# 1   Change item # on garment from 1937.095.001 a t...  Lawrence, Sherry
# 2                                                 NaN  Lawrence, Sherry
# 3   Change Item # on garment from 1937.095.001 c t...               NaN
# 4   Coat worn by Infantry Capt. Dennis H. Williams...  Goodmanson, Erik
# 5   Minnie Dansingburg married Walter J. Airs on O...  Lawrence, Sherry
# 6   Wedding dress of Martha Helen Cross, who marri...  Lawrence, Sherry
# 7   Donation made by Flora Bliss and her sister, M...  Lawrence, Sherry
# 8                                                 NaN  Lawrence, Sherry
# 9                                                 NaN               NaN
# 10                                                NaN  Goodmanson, Erik
#
#       invndate material
# 1   2006-07-20  Textile
# 2   2006-07-20  Textile
# 3          NaN  Textile
# 4   2019-06-13  Textile
# 5   2006-08-17  Textile
# 6   2006-08-17  Textile
# 7   2006-08-17  Textile
# 8   2006-08-21  Textile
# 9          NaN      NaN
# 10  2020-10-15  Textile

# %%
new_df.to_csv('migrate_data.csv')
